# %% [markdown]
# <a href="https://colab.research.google.com/github/ziyacanyldz/inme-tahmini/blob/main/D2_%C4%B0nmeVeriseti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd ; import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
from google.colab import files
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-01e1a456-544e-43d8-bd46-1ae350a76f0f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-01e1a456-544e-43d8-bd46-1ae350a76f0f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving inme_veriseti.csv to inme_veriseti.csv

# %%
import io
veri = pd.read_csv(io.BytesIO(uploaded['inme_veriseti.csv']))
veri
# Out:
#          id  gender   age  ...   bmi   smoking_status stroke
# 0      9046    Male  67.0  ...  36.6  formerly smoked      1
# 1     51676  Female  61.0  ...   NaN     never smoked      1
# 2     31112    Male  80.0  ...  32.5     never smoked      1
# 3     60182  Female  49.0  ...  34.4           smokes      1
# 4      1665  Female  79.0  ...  24.0     never smoked      1
# ...     ...     ...   ...  ...   ...              ...    ...
# 5105  18234  Female  80.0  ...   NaN     never smoked      0
# 5106  44873  Female  81.0  ...  40.0     never smoked      0
# 5107  19723  Female  35.0  ...  30.6     never smoked      0
# 5108  37544    Male  51.0  ...  25.6  formerly smoked      0
# 5109  44679  Female  44.0  ...  26.2          Unknown      0
#
# [5110 rows x 12 columns]

# %% [markdown]
# Çalışma tipi serbest meslek olanların inme geçirme oranı daha yüksek , ardından özel şirketlerde çalışanlar ve devlet kurumlarında çalışanlar geliyor.

# %%
grup = veri.groupby("work_type")
grup["stroke"].mean().plot(kind = "bar")

# %% [markdown]
# Hipertansiyonu olanların inme geçirme oranı daha yüksek

# %%
grup2 = veri.groupby("hypertension")
grup2["stroke"].mean().plot(kind = "bar")

# %% [markdown]
# İnme hastalarının yaş ortalaması 60-70 arası. İnme hastası olmayanların yaş ortalaması 40-45 arası

# %%
grup3 = veri.groupby("stroke")
grup3["age"].mean().plot(kind = "bar")

# %% [markdown]
# Sigara içen veya önceden sigara kullananların inme geçirme oranı hiç içmeyen insanlara göre daha fazla

# %%
grup4 = veri.groupby("smoking_status")
grup4["stroke"].mean().plot(kind = "bar")

# %% [markdown]
# Çalışma durumu ve sigara kullanma durumu ele alındığında inme geçirme oranı en yüksek olan grup serbest meslek yapıp önceden sigara kullanan insanlar.

# %%
grup5 = veri.groupby(["work_type","smoking_status"])
grup5["stroke"].mean().plot(kind = "bar")

# %% [markdown]
# Hipertansiyon ve kalp hastalığı durumu ele alındığında kalp hastası olanların inme geçirme oranı tansiyon hastalarına göre daha fazla. İki hastalığada birden sahip olan insanların inme geçirme oranı daha yüksek.

# %%
grup6 = veri.groupby(["hypertension","heart_disease"])
grup6["stroke"].mean().plot(kind = "bar")

# %% [markdown]
# Cinsiyet ve evlilik durumu ele alındığında evli olanların inme geçirme oranı daha yüksek olduğu gözüküyor. İnme geçirme oranı en fazla olan grup evli ve erkek olanlar.

# %%
grup7 = veri.groupby(["gender","ever_married"])
grup7["stroke"].mean().plot(kind = "bar")

# %% [markdown]
# İkamet türü ele alındığında şehirde yaşayanların inme geçirme oranı kırsalda yaşayanlara göre daha fazla.

# %%
veri[veri.stroke == 1].Residence_type.value_counts(normalize = True).plot(kind = "bar")

# %% [markdown]
# Aşağıdaki grafikte çalışma tipine göre sigara içme durumları incelenmiş.

# %%
calısma_tipi_sigara = pd.crosstab(veri["work_type"] , veri["smoking_status"])
calısma_tipi_sigara.plot.bar()

# %% [markdown]
# Evli olanların inme geçirme oranı daha yüksek.

# %%
import seaborn as sns 
sns.barplot(x="ever_married" , y="stroke" , data = veri , orient = "v")

# %% [markdown]
# Veri setindeki verilerin yaş dağılımı aşağıdaki gibidir.

# %%
sns.distplot(veri["age"] , bins=50)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Veri setindeki verilerin vücut kitle indeksi dağılımı aşağıdaki gibidir.

# %%
sns.distplot(veri["bmi"] , bins=50 , color = "r")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Yaşın artmasıyla birlikte inme hastalarının sayısı da doğrusal olarak artıyor.

# %%
sns.regplot("age" , "stroke" , data = veri)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Ortalama glikoz seviyesi arttıkça inme hastalarının sayısı da doğrusal olarak artıyor.

# %%
sns.regplot("avg_glucose_level" , "stroke" , data = veri)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Vücut kitle indeksi arttıkça inme hastalarının sayısı da doğrusal olarak artıyor. Grafiğe göre bu artış eğrisi yukarıdaki yaş ve ortalama glikoz seviyesi grafiğiklerine kıyasla daha düşük gözüküyor.

# %%
sns.regplot("bmi" , "stroke" , data = veri)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
veri.avg_glucose_level.plot()

# %%
korelasyon = veri.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(korelasyon, annot=True, vmin=-1.0, cmap="terrain")
plt.title("Isı Haritası")
plt.show()

# %%
sns.pairplot(veri , hue = "stroke")

# %%
del veri["id"]

# %%
veri.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
veri.dropna(subset=["bmi"],inplace=True)

# %%
veri.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
veri['gender'] = veri['gender'].replace({'Male':0,'Female':1,'Other':-1}).astype(np.uint8)
veri['Residence_type'] = veri['Residence_type'].replace({'Rural':0,'Urban':1}).astype(np.uint8)
veri['work_type'] = veri['work_type'].replace({'Private':0,'Self-employed':1,'Govt_job':2,'children':-1,'Never_worked':-2}).astype(np.uint8)
veri['ever_married'] = veri['ever_married'].replace({'Yes':1, 'No':0}).astype(np.uint8)
veri['smoking_status'] = veri['smoking_status'].replace({'never smoked':0,'Unknown':1,'formerly smoked':2,'smokes':-1}).astype(np.uint8)

# %%
veri
# Out:
#       gender   age  hypertension  ...   bmi  smoking_status  stroke
# 0          0  67.0             0  ...  36.6               2       1
# 2          0  80.0             0  ...  32.5               0       1
# 3          1  49.0             0  ...  34.4             255       1
# 4          1  79.0             1  ...  24.0               0       1
# 5          0  81.0             0  ...  29.0               2       1
# ...      ...   ...           ...  ...   ...             ...     ...
# 5104       1  13.0             0  ...  18.6               1       0
# 5106       1  81.0             0  ...  40.0               0       0
# 5107       1  35.0             0  ...  30.6               0       0
# 5108       0  51.0             0  ...  25.6               2       0
# 5109       1  44.0             0  ...  26.2               1       0
#
# [4909 rows x 11 columns]

# %%
veri['stroke'].value_counts()
# Out:
# 0    4700
# 1     209
# Name: stroke, dtype: int64

# %%
x = veri.drop('stroke' , axis = 1)

# %%
y = veri['stroke']

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()
x_resh, y_resh = oversample.fit_resample(x , y.ravel())

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test =  train_test_split(x_resh, y_resh , test_size=0.20 ,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import  SVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB 
from sklearn.naive_bayes import BernoulliNB


models = {
    "             Logistic Regression      ": LogisticRegression(max_iter=1000),
    "             K-Nearest Neighbors      ": KNeighborsClassifier(),
    "               Decision Tree          ": DecisionTreeClassifier(),
    "             SVM (RBF Kernel)         ": SVC(),
    "              Neural Network          ": MLPClassifier(),
    "               Random Forest          ": RandomForestClassifier(),
    "             Gradient Boosting        ": GradientBoostingClassifier(),
    "                  XGBoost             ": XGBClassifier(eval_metric='mlogloss'),
    "                 Gaussian NB          ": GaussianNB(),
    "                BernoulliNB           ": BernoulliNB()
         
}

for name, model in models.items():
    model.fit(x_train, y_train)
    print(name + " algoritması eğitildi.")
# Out:
#              Logistic Regression       algoritması eğitildi.
#              K-Nearest Neighbors       algoritması eğitildi.
#                Decision Tree           algoritması eğitildi.
#              SVM (RBF Kernel)          algoritması eğitildi.
#               Neural Network           algoritması eğitildi.
#                Random Forest           algoritması eğitildi.
#              Gradient Boosting         algoritması eğitildi.
#                   XGBoost              algoritması eğitildi.
#                  Gaussian NB           algoritması eğitildi.
#                 BernoulliNB            algoritması eğitildi.

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import cross_val_score

# %%
print("\t\t\t\tModel Performansı TRAIN\n\t\t\t\t-----------------------")
for name, model in models.items():
    y_tahmin = model.predict(x_train)
    print(
        "\n" + name + " Doğruluk: {:.3f}%\n\t\t\t\t       F1-Score: {:.5f}"\
        .format(accuracy_score(y_train, y_tahmin) * 100, f1_score(y_train, y_tahmin))
    )
print("\n\n\t\t\t\tModel Performansı TEST\n\t\t\t\t----------------------")
for name, model in models.items():
    y_tahmin = model.predict(x_test)
    print(
        "\n" + name + " Doğruluk: {:.3f}%\n\t\t\t\t       F1-Score: {:.5f}"\
        .format(accuracy_score(y_test, y_tahmin) * 100, f1_score(y_test, y_tahmin))
    )
# Out:
# 				Model Performansı TRAIN
# 				-----------------------
#
#              Logistic Regression       Doğruluk: 80.585%
# 				       F1-Score: 0.80960
#
#              K-Nearest Neighbors       Doğruluk: 91.928%
# 				       F1-Score: 0.92453
#
#                Decision Tree           Doğruluk: 100.000%
# 				       F1-Score: 1.00000
#
#              SVM (RBF Kernel)          Doğruluk: 77.035%
# 				       F1-Score: 0.78120
#
#               Neural Network           Doğruluk: 83.710%
# 				       F1-Score: 0.84609
#
#                Random Forest           Doğruluk: 100.000%
# 				       F1-Score: 1.00000
#
#              Gradient Boosting         Doğruluk: 88.205%
# 				       F1-Score: 0.88550
#
#                   XGBoost              Doğruluk: 87.832%
# 				       F1-Score: 0.88250
#
#                  Gaussian NB           Doğruluk: 71.144%
# 				       F1-Score: 0.77363
#
#                 BernoulliNB            Doğruluk: 67.899%
# 				       F1-Score: 0.69130
#
#
# 				Model Performansı TEST
# 				----------------------
#
#              Logistic Regression       Doğruluk: 79.468%
# 				       F1-Score: 0.80144
#
#              K-Nearest Neighbors       Doğruluk: 88.670%
# 				       F1-Score: 0.89655
#
#                Decision Tree           Doğruluk: 91.011%
# 				       F1-Score: 0.91275
#
#              SVM (RBF Kernel)          Doğruluk: 77.074%
# 				       F1-Score: 0.78243
#
#               Neural Network           Doğruluk: 82.287%
# 				       F1-Score: 0.83308
#
#                Random Forest           Doğruluk: 94.787%
# 				       F1-Score: 0.94922
#
#              Gradient Boosting         Doğruluk: 86.543%
# 				       F1-Score: 0.87032
#
#                   XGBoost              Doğruluk: 86.330%
# 				       F1-Score: 0.86987
#
#                  Gaussian NB           Doğruluk: 71.170%
# 				       F1-Score: 0.77473
#
#                 BernoulliNB            Doğruluk: 69.096%
# 				       F1-Score: 0.70251

# %%
print("\t\t\t\tCross Validation Score\n\t\t\t\t-----------------------")
for name, model in models.items():
    print(name + " Cross val score: {0:.2f}".format(cross_val_score(model , x_resh , y_resh , cv=5).mean() * 100) +"%")
# Out:
# 				Cross Validation Score
# 				-----------------------
#              Logistic Regression       Cross val score: 80.50%
#              K-Nearest Neighbors       Cross val score: 89.15%
#                Decision Tree           Cross val score: 90.99%
#              SVM (RBF Kernel)          Cross val score: 77.11%
#               Neural Network           Cross val score: 82.50%
#                Random Forest           Cross val score: 94.22%
#              Gradient Boosting         Cross val score: 86.41%
#                   XGBoost              Cross val score: 86.38%
#                  Gaussian NB           Cross val score: 71.77%
#                 BernoulliNB            Cross val score: 68.18%

# %%
fig = plt.figure(figsize=(16,4))

ax = fig.add_axes([0,0,1,1])

for name, model in models.items():
    y_tahmin = model.predict(x_train)
    ax.bar(name, accuracy_score(y_train, y_tahmin) * 100, width=0.4, )

plt.title("Train doğruluk değerlerinin sütun grafiği", fontsize = 20)
plt.xlabel('Algoritmalar', fontsize = 20)
plt.ylabel('Doğruluk değerleri', fontsize = 20)
plt.rcParams.update({'font.size': 11})


plt.show()

# %%
fig = plt.figure(figsize=(16,4))

ax = fig.add_axes([0,0,1,1])

for name, model in models.items():
    y_tahmin = model.predict(x_test)
    ax.bar(name, accuracy_score(y_test, y_tahmin) * 100, width=0.4, )

plt.title("Test doğruluk değerlerinin sütun grafiği", fontsize = 20)
plt.xlabel('Algoritmalar', fontsize = 20)
plt.ylabel('Doğruluk değerleri', fontsize = 20)
plt.rcParams.update({'font.size': 11})


plt.show()

# %%
#modellere göre confusion matrixi ile dengesizliklere baktık

from sklearn.metrics import confusion_matrix

for name, model in models.items():
    y_tahmin = model.predict(x_test)
    print(name, "\n", confusion_matrix(y_test , y_tahmin, labels=[0,1]), "\n")
# Out:
#              Logistic Regression
#  [[715 219]
#  [167 779]]
#
#              K-Nearest Neighbors
#  [[744 190]
#  [ 23 923]]
#
#                Decision Tree
#  [[827 107]
#  [ 62 884]]
#
#              SVM (RBF Kernel)
#  [[674 260]
#  [171 775]]
#
#               Neural Network
#  [[716 218]
#  [115 831]]
#
#                Random Forest
#  [[866  68]
#  [ 30 916]]
#
#              Gradient Boosting
#  [[778 156]
#  [ 97 849]]
#
#                   XGBoost
#  [[764 170]
#  [ 87 859]]
#
#                  Gaussian NB
#  [[406 528]
#  [ 14 932]]
#
#                 BernoulliNB
#  [[613 321]
#  [260 686]]

# %%
import sklearn.metrics as metrics


for name, model in models.items():
    y_tahmin = model.predict(x_test)
    fpr , tpr , thresholds = metrics.roc_curve(y_test , y_tahmin)
    roc_auc = metrics.auc(fpr , tpr)
    plt.plot(fpr , tpr ,'b' ,label = 'AUC =0.2f' %roc_auc)
    print(name, roc_auc)
# Out:
#              Logistic Regression       0.7944959278558202
#              K-Nearest Neighbors       0.886130489698539
#                Decision Tree           0.9099499300560004
#              SVM (RBF Kernel)          0.7704331548139127
#               Neural Network           0.8225154035248154
#                Random Forest           0.9477411936203828
#              Gradient Boosting         0.8652197237551553
#                   XGBoost              0.8630104893363694
#                  Gaussian NB           0.7099451765803043
#                 BernoulliNB            0.6907377394280437

# %%
models2 = {
    "             Logistic Regression      ": LogisticRegression(C= 0.23357214690901212, max_iter= 1000, penalty= 'l2'),
    "             K-Nearest Neighbors      ": KNeighborsClassifier(n_neighbors=2, p=2),
    "               Decision Tree          ": DecisionTreeClassifier(criterion= 'entropy', max_depth= 70),
    "             SVM (RBF Kernel)         ": SVC(C= 5, gamma= 0.1),
    "              Neural Network          ": MLPClassifier(activation= 'tanh', alpha= 0.0001, hidden_layer_sizes= (100,), learning_rate= 'adaptive', max_iter= 1000, solver= 'adam'),
    "               Random Forest          ": RandomForestClassifier(max_depth= 30, max_features= 'auto', min_samples_leaf= 1, min_samples_split= 3, n_estimators= 700),
    "             Gradient Boosting        ": GradientBoostingClassifier(learning_rate= 0.1, loss= 'exponential', max_depth= 9, n_estimators= 500, subsample= 0.5),
    "                  XGBoost             ": XGBClassifier(learning_rate= 0.1, max_depth= 8, n_estimators= 180),
    "                 Gaussian NB          ": GaussianNB(var_smoothing= 0.0012328467394420659),
    "                BernoulliNB           ": BernoulliNB(alpha= 10.0)
         
}

for name, model in models2.items():
    model.fit(x_train, y_train)
    print(name + " algoritması eğitildi.")
# Out:
#              Logistic Regression       algoritması eğitildi.
#              K-Nearest Neighbors       algoritması eğitildi.
#                Decision Tree           algoritması eğitildi.
#              SVM (RBF Kernel)          algoritması eğitildi.
#               Neural Network           algoritması eğitildi.
#                Random Forest           algoritması eğitildi.
#              Gradient Boosting         algoritması eğitildi.
#                   XGBoost              algoritması eğitildi.
#                  Gaussian NB           algoritması eğitildi.
#                 BernoulliNB            algoritması eğitildi.

# %%
print("\t\t\t\tModel Performansı TRAIN\n\t\t\t\t-----------------------")
for name, model in models2.items():
    y_tahmin = model.predict(x_train)
    print(
        "\n" + name + " Doğruluk: {:.3f}%\n\t\t\t\t       F1-Score: {:.5f}"\
        .format(accuracy_score(y_train, y_tahmin) * 100, f1_score(y_train, y_tahmin))
    )
print("\n\n\t\t\t\tModel Performansı TEST\n\t\t\t\t----------------------")
for name, model in models2.items():
    y_tahmin = model.predict(x_test)
    print(
        "\n" + name + " Doğruluk: {:.3f}%\n\t\t\t\t       F1-Score: {:.5f}"\
        .format(accuracy_score(y_test, y_tahmin) * 100, f1_score(y_test, y_tahmin))
    )
# Out:
# 				Model Performansı TRAIN
# 				-----------------------
#
#              Logistic Regression       Doğruluk: 80.465%
# 				       F1-Score: 0.80934
#
#              K-Nearest Neighbors       Doğruluk: 98.936%
# 				       F1-Score: 0.98923
#
#                Decision Tree           Doğruluk: 100.000%
# 				       F1-Score: 1.00000
#
#              SVM (RBF Kernel)          Doğruluk: 99.814%
# 				       F1-Score: 0.99814
#
#               Neural Network           Doğruluk: 91.064%
# 				       F1-Score: 0.91444
#
#                Random Forest           Doğruluk: 100.000%
# 				       F1-Score: 1.00000
#
#              Gradient Boosting         Doğruluk: 100.000%
# 				       F1-Score: 1.00000
#
#                   XGBoost              Doğruluk: 99.574%
# 				       F1-Score: 0.99574
#
#                  Gaussian NB           Doğruluk: 71.662%
# 				       F1-Score: 0.77721
#
#                 BernoulliNB            Doğruluk: 68.431%
# 				       F1-Score: 0.69873
#
#
# 				Model Performansı TEST
# 				----------------------
#
#              Logistic Regression       Doğruluk: 79.521%
# 				       F1-Score: 0.80327
#
#              K-Nearest Neighbors       Doğruluk: 92.074%
# 				       F1-Score: 0.92331
#
#                Decision Tree           Doğruluk: 92.500%
# 				       F1-Score: 0.92698
#
#              SVM (RBF Kernel)          Doğruluk: 95.213%
# 				       F1-Score: 0.95342
#
#               Neural Network           Doğruluk: 88.777%
# 				       F1-Score: 0.89413
#
#                Random Forest           Doğruluk: 94.681%
# 				       F1-Score: 0.94835
#
#              Gradient Boosting         Doğruluk: 97.340%
# 				       F1-Score: 0.97388
#
#                   XGBoost              Doğruluk: 95.798%
# 				       F1-Score: 0.95888
#
#                  Gaussian NB           Doğruluk: 71.277%
# 				       F1-Score: 0.77593
#
#                 BernoulliNB            Doğruluk: 69.309%
# 				       F1-Score: 0.70636

# %%
print("\t\t\t\tCross Validation Score\n\t\t\t\t-----------------------")
for name, model in models2.items():
    print(name + " Cross val score: {0:.2f}".format(cross_val_score(model , x_resh , y_resh , cv=5).mean() * 100) +"%")
# Out:
# 				Cross Validation Score
# 				-----------------------
#              Logistic Regression       Cross val score: 80.04%
#              K-Nearest Neighbors       Cross val score: 91.66%
#                Decision Tree           Cross val score: 91.48%
#              SVM (RBF Kernel)          Cross val score: 94.84%
#               Neural Network           Cross val score: 88.29%
#                Random Forest           Cross val score: 94.69%
#              Gradient Boosting         Cross val score: 96.55%
#                   XGBoost              Cross val score: 95.95%
#                  Gaussian NB           Cross val score: 71.85%
#                 BernoulliNB            Cross val score: 68.65%

# %%
fig = plt.figure(figsize=(16,4))

ax = fig.add_axes([0,0,1,1])

for name, model in models2.items():
    y_tahmin = model.predict(x_train)
    ax.bar(name, accuracy_score(y_train, y_tahmin) * 100, width=0.4, )

plt.title("Train doğruluk değerlerinin sütun grafiği", fontsize = 20)
plt.xlabel('Algoritmalar', fontsize = 20)
plt.ylabel('Doğruluk değerleri', fontsize = 20)
plt.rcParams.update({'font.size': 11})


plt.show()

# %%
fig = plt.figure(figsize=(16,4))

ax = fig.add_axes([0,0,1,1])

for name, model in models2.items():
    y_tahmin = model.predict(x_test)
    ax.bar(name, accuracy_score(y_test, y_tahmin) * 100, width=0.4, )

plt.title("Test doğruluk değerlerinin sütun grafiği", fontsize = 20)
plt.xlabel('Algoritmalar', fontsize = 20)
plt.ylabel('Doğruluk değerleri', fontsize = 20)
plt.rcParams.update({'font.size': 11})


plt.show()

# %%
#modellere göre confusion matrixi ile dengesizliklere baktık

from sklearn.metrics import confusion_matrix

for name, model in models2.items():
    y_tahmin = model.predict(x_test)
    print(name, "\n", confusion_matrix(y_test , y_tahmin, labels=[0,1]), "\n")
# Out:
#              Logistic Regression
#  [[709 225]
#  [160 786]]
#
#              K-Nearest Neighbors
#  [[834 100]
#  [ 49 897]]
#
#                Decision Tree
#  [[844  90]
#  [ 51 895]]
#
#              SVM (RBF Kernel)
#  [[869  65]
#  [ 25 921]]
#
#               Neural Network
#  [[778 156]
#  [ 55 891]]
#
#                Random Forest
#  [[862  72]
#  [ 28 918]]
#
#              Gradient Boosting
#  [[898  36]
#  [ 14 932]]
#
#                   XGBoost
#  [[880  54]
#  [ 25 921]]
#
#                  Gaussian NB
#  [[405 529]
#  [ 11 935]]
#
#                 BernoulliNB
#  [[609 325]
#  [252 694]]

# %%
import sklearn.metrics as metrics


for name, model in models2.items():
    y_tahmin = model.predict(x_test)
    fpr , tpr , thresholds = metrics.roc_curve(y_test , y_tahmin)
    roc_auc = metrics.auc(fpr , tpr)
    plt.plot(fpr , tpr ,'b' ,label = 'AUC =0.2f' %roc_auc)
    print(name, roc_auc)
# Out:
#              Logistic Regression       0.7949837250046402
#              K-Nearest Neighbors       0.9205682893372749
#                Decision Tree           0.9248645259426593
#              SVM (RBF Kernel)          0.951989895468806
#               Neural Network           0.8874184552562122
#                Random Forest           0.9466569484496878
#              Gradient Boosting         0.973328474224844
#                   XGBoost              0.9578785464324033
#                  Gaussian NB           0.7109954683531696
#                 BernoulliNB            0.6928247416146426

# %%
crossval_scores = [] * 10
crossval_name = [] * 10

for name, model in models.items():
  crossval_name.append(name)
  crossval_scores.append(float(cross_val_score(model , x_resh , y_resh , cv=5).mean() * 100))

# %%
crossval_scores2 = [] * 10
crossval_name2 = [] * 10

for name, model in models2.items():
  crossval_name2.append(name)
  crossval_scores2.append(float(cross_val_score(model , x_resh , y_resh , cv=5).mean() * 100))

# %%
fig = plt.figure(figsize=(25,7))

ax = fig.add_axes([0,0,1,1])

x = np.arange(len(crossval_name))
width = 0.35 
rects1 = ax.bar(x - width/2, crossval_scores, width, label='Default', color='purple')
rects2 = ax.bar(x + width/2, crossval_scores2, width, label='Hyper-Parametre', color= 'red')

plt.title("Default ve Hyper-Parametreli modellerin cross validation değerlerinin sütun grafiği", fontsize = 20)
plt.xlabel('Algoritmalar', fontsize = 20)
plt.ylabel('CrossValidation değerleri', fontsize = 20)
ax.set_xticks(x)
ax.set_xticklabels(crossval_name)
ax.legend()
plt.rcParams.update({'font.size': 15})


plt.show()
